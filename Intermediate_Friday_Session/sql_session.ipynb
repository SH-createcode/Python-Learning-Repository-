# %%
from sqlalchemy import (create_engine, 
                        inspect, 
                        text, 
                        select, 
                        MetaData, 
                        Table, 
                        and_,
                        or_,
                        desc,
                        asc,
                        func,
                        )


engine_903 = create_engine("sqlite+pysqlite:////workspaces/Python-Learning-Repository-/Intermediate_Friday_Session/903_database.db")

connection = engine_903.connect()
inspection = inspect(engine_903)
inspection.get_table_names()
# Out:
# ['ad1',
#  'episodes',
#  'header',
#  'missing',
#  'oc2',
#  'oc3',
#  'placed_for_adoption',
#  'previous_permenance',
#  'reviews',
#  'uasc']

# %%
engine_chinook = create_engine("sqlite+pysqlite:////workspaces/Python-Learning-Repository-/Intermediate_Friday_Session/chinook.db")

connection = engine_chinook.connect()
inpection = inspect(engine_chinook)
inpection.get_table_names()
# Out:
# ['albums',
#  'artists',
#  'customers',
#  'employees',
#  'genres',
#  'invoice_items',
#  'invoices',
#  'media_types',
#  'playlist_track',
#  'playlists',
#  'tracks']

# %%
metadata_903 = MetaData()

episodes = Table('episodes',metadata_903, autoload_with=engine_903)

print(episodes.name)
print(episodes.c.keys())
print(repr(episodes))
# Out:
# episodes
# ['index', 'CHILD', 'DECOM', 'RNE', 'LS', 'CIN', 'PLACE', 'PLACE_PROVIDER', 'DEC', 'REC', 'REASON_PLACE_CHANGE', 'HOME_POST', 'PL_POST', 'URN']
# Table('episodes', MetaData(), Column('index', INTEGER(), table=<episodes>), Column('CHILD', INTEGER(), table=<episodes>), Column('DECOM', TEXT(), table=<episodes>), Column('RNE', TEXT(), table=<episodes>), Column('LS', TEXT(), table=<episodes>), Column('CIN', TEXT(), table=<episodes>), Column('PLACE', TEXT(), table=<episodes>), Column('PLACE_PROVIDER', TEXT(), table=<episodes>), Column('DEC', TEXT(), table=<episodes>), Column('REC', TEXT(), table=<episodes>), Column('REASON_PLACE_CHANGE', TEXT(), table=<episodes>), Column('HOME_POST', TEXT(), table=<episodes>), Column('PL_POST', TEXT(), table=<episodes>), Column('URN', INTEGER(), table=<episodes>), schema=None)

# %%
metadata_chinook = MetaData()

albums = Table('albums', metadata_chinook, autoload_with=engine_chinook)

print(albums.name)
print(albums.c.keys())
print(repr(albums))
# Out:
# albums
# ['AlbumId', 'Title', 'ArtistId']
# Table('albums', MetaData(), Column('AlbumId', INTEGER(), table=<albums>, primary_key=True, nullable=False), Column('Title', NVARCHAR(length=160), table=<albums>, nullable=False), Column('ArtistId', INTEGER(), ForeignKey('artists.ArtistId'), table=<albums>, nullable=False), schema=None)

# %%
from sqlalchemy import create_engine, MetaData, Table


# 2. Create metadata
metadata_chinook = MetaData()

# 3. Reflect table structure
albums = Table(
    'albums',
    metadata_chinook,
    autoload_with=engine_chinook
)

# 4. Test outputs
print(albums.name)
print(albums.c.keys())
print(repr(albums))
# Out:
# ---------------------------------------------------------------------------
# NoSuchTableError                          Traceback (most recent call last)
# Cell In[23], line 10
#       7 metadata_chinook = MetaData()
#       9 # 3. Reflect table structure
# ---> 10 albums = Table(
#      11     'albums',
#      12     metadata_chinook,
#      13     autoload_with=engine_chinook
#      14 )
#      16 # 4. Test outputs
#      17 print(albums.name)
#
# File <string>:2, in __new__(cls, *args, **kw)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# ...
